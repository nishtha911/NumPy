# %%
import numpy as np

# %%
arr = np.array([])

# %%
arr.ndim
# Out:
# 3

# %%
arr.shape
# Out:
# (1, 1, 0)

# %%
range1 = np.arange(1,10, 2)

# %%
range1
# Out:
# array([1, 3, 5, 7, 9])

# %%
arr = np.logspace(1, 3, 3)
arr
# Out:
# array([  10.,  100., 1000.])

# %%
arr = np.array([10000000,2,3,4,5])
arr
# Out:
# array([10000000,        2,        3,        4,        5])

# %%
arr.dtype
# Out:
# dtype('int32')
